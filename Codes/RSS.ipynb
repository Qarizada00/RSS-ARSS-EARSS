# %%
#Some Codes are taken from Lab Chapter Slides.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.ticker as ticker
import plotly.graph_objs as go
import plotly.offline as py
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
dataset = pd.read_excel("C:/Users/Nasibullah Qarizada/Desktop/data science/term project/AllDataARSAA.xlsx")

# %% [markdown]
# **Usefulness - RSS**

# %%
Performance = dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:']
Productivity = dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:']
Effectivness = dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:']
Usefull = dataset['I find this scenario useful:After looking at the pictures please rate the following statements:']
total_usefulness = dataset['Total Usefulnes - RSS']

df=pd.DataFrame()
df['Performance']=Performance
df['Productivity']=Productivity
df['Effectivness']=Effectivness
df['Usefull']=Usefull

fig, ax =plt.subplots(2,2)
sns.distplot(df['Performance'], ax=ax[0,0])
sns.distplot(df['Productivity'], ax=ax[0,1])
sns.distplot(df['Effectivness'], ax=ax[1,0])
sns.distplot(df['Usefull'], ax=ax[1,1])
sns.set(rc={'figure.figsize':(25.0,8.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21880/1639669520.py:19: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# **Usefullness**

# %%
print (dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:'].mean(), 
dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:'].mean(), 
dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:'].mean(), 
dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['I find this scenario useful:After looking at the pictures please rate the following statements:'].mean(), 
dataset['I find this scenario useful:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['I find this scenario useful:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['Total Usefulnes - RSS'].mean(), 
dataset['Total Usefulnes - RSS'].std(), 
float(dataset['Total Usefulnes - RSS'].median()))
# Out:
# 2.761904761904762 0.9313364550403863 3.0
# 2.8134920634920637 0.966024685587202 3.0
# 2.8174603174603177 0.9310987695930812 3.0
# 3.1031746031746033 0.8776041732638479 3.0
# 2.8740079365079363 0.7951227121814602 3.0

# %% [markdown]
# **Entertainment - RSS**

# %%
Enjoyable = dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:']
Pleasing = dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:']
Entertaining = dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:']



df=pd.DataFrame()
df['Enjoyable']=Enjoyable
df['Pleasing']=Pleasing
df['Entertaining']=Entertaining



fig, ax = plt.subplots(2,2)
sns.distplot(df['Enjoyable'], ax=ax[0,0])
sns.distplot(df['Pleasing'], ax=ax[0,1])
sns.distplot(df['Entertaining'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(20.0,8.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21880/1302310257.py:19: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:'].mean(), 
dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:'].mean(), 
dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:'].mean(), 
dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['Total Enjoyment - RSS'].mean(), 
dataset['Total Enjoyment - RSS'].std(), 
float(dataset['Total Enjoyment - RSS'].median()))
# Out:
# 2.873015873015873 0.9529499343807555 3.0
# 3.0317460317460316 0.8509334732401852 3.0
# 2.5476190476190474 1.0068066582645259 2.0
# 2.8174603174603186 0.8198588103943382 3.0

# %% [markdown]
# **Information**

# %%
Good_Source_Of_Information = dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:']
Relevent_Information = dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:']
Informative = dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:']


df=pd.DataFrame()
df['Good_Source_Of_Information']=Good_Source_Of_Information
df['Relevent_Information']=Relevent_Information
df['Informative']=Informative


fig, ax = plt.subplots(2,2)
sns.distplot(df['Good_Source_Of_Information'], ax=ax[0,0])
sns.distplot(df['Relevent_Information'], ax=ax[0,1])
sns.distplot(df['Informative'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(20.0,8.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21880/236234964.py:17: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:'].mean(), 
dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:'].mean(), 
dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:'].mean(), 
dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['Total Information - RSS'].mean(), 
dataset['Total Information - RSS'].std(), 
float(dataset['Total Information - RSS'].median()))
# Out:
# 2.7857142857142856 1.014690052235589 2.0
# 3.0992063492063493 1.0381561982243892 4.0
# 2.876984126984127 1.0003714607624525 3.0
# 2.9206349206349205 0.9151023198194557 3.0

# %% [markdown]
# **Irritiation**

# %%
Annoying = dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:']
Frustrating = dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:']
Irritating = dataset['This scenario is irritating:After looking at the pictures please rate the following statements:']


df=pd.DataFrame()
df['Annoying']=Annoying
df['Frustrating']=Frustrating
df['Irritating']=Irritating



fig, ax = plt.subplots(2,2)
sns.distplot(df['Annoying'], ax=ax[0,0])
sns.distplot(df['Frustrating'], ax=ax[0,1])
sns.distplot(df['Irritating'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21880/4195671271.py:18: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:'].mean(), 
dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:'].mean(), 
dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['This scenario is irritating:After looking at the pictures please rate the following statements:'].mean(), 
dataset['This scenario is irritating:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['This scenario is irritating:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['Total Irritation - RSS'].mean(), 
dataset['Total Irritation - RSS'].std(), 
float(dataset['Total Irritation - RSS'].median()))
# Out:
# 2.3293650793650795 1.032659311021905 2.0
# 2.2261904761904763 1.0218862780015698 2.0
# 2.123015873015873 1.0003714607624523 2.0
# 2.2261904761904767 0.844471195827188 2.0

# %% [markdown]
# **Purchase intention**

# %%
Definitly_buy = dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:']
Intend_to_purchase = dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:']
purchase_in_future = dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:']
buy_now = dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:']


df=pd.DataFrame()
df['Definitly_buy']=Definitly_buy
df['Intend_to_purchase']=Intend_to_purchase
df['purchase_in_future']=purchase_in_future
df['buy_now']=buy_now

fig, ax = plt.subplots(2,3)
sns.distplot(df['Definitly_buy'], ax=ax[0,0])
sns.distplot(df['Intend_to_purchase'], ax=ax[0,1])
sns.distplot(df['purchase_in_future'], ax=ax[0,2])
sns.distplot(df['buy_now'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21880/508616691.py:19: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:'].mean(), 
dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:'].mean(), 
dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:'].mean(), 
dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:'].mean(), 
dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:'].std(), 
float(dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:'].mode()))

print (dataset['Total Purchase Intention - RSS'].mean(), 
dataset['Total Purchase Intention - RSS'].std(), 
float(dataset['Total Purchase Intention - RSS'].median()))
# Out:
# 3.0873015873015874 1.03346276140007 3.0
# 3.1825396825396823 0.9225013082688122 3.0
# 3.1865079365079363 0.9984731909691773 3.0
# 3.1984126984126986 0.9698222720478314 3.0
# 3.1636904761904763 0.8678871809131632 3.25

# %%
print((dataset['Total Usefulnes - RSS'].mean() +
dataset['Total Enjoyment - RSS'].mean() +
dataset['Total Information - RSS'].mean() +
dataset['Total Irritation - RSS'].mean() +
dataset['Total Purchase Intention - RSS'].mean()) / 5)
# Out:
# 2.8003968253968257

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Usefulnes - RSS'].mean()
median=dataset['Total Usefulnes - RSS'].median()
mode=dataset['Total Usefulnes - RSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Usefulnes - RSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Usefulnes - RSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Enjoyment - RSS'].mean()
median=dataset['Total Enjoyment - RSS'].median()
mode=dataset['Total Enjoyment - RSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Enjoyment - RSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Enjoyment - RSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Information - RSS'].mean()
median=dataset['Total Information - RSS'].median()
mode=dataset['Total Information - RSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Information - RSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Information - RSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Irritation - RSS'].mean()
median=dataset['Total Irritation - RSS'].median()
mode=dataset['Total Irritation - RSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Irritation - RSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Irritation - RSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Purchase Intention - RSS'].mean()
median=dataset['Total Purchase Intention - RSS'].median()
mode=dataset['Total Purchase Intention - RSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Purchase Intention - RSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Purchase Intention - RSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()
