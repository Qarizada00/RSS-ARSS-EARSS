# %%
#Inspired from Lecute slides
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.ticker as ticker
import plotly.graph_objs as go
import plotly.offline as py
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
dataset = pd.read_excel('C:/Users/Nasibullah Qarizada/Desktop/data science/term project/AllDataARSAA.xlsx')

# %% [markdown]
# **Usefulness - EARSS**

# %%
Performance = dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:3']
Productivity = dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:3']
Effectivness = dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:3']
Usefull = dataset['I find this scenario useful:After looking at the pictures please rate the following statements:3']

df=pd.DataFrame()
df['Performance']=Performance
df['Productivity']=Productivity
df['Effectivness']=Effectivness
df['Usefull']=Usefull

fig, ax =plt.subplots(2,3)
sns.distplot(df['Performance'], ax=ax[0,0])
sns.distplot(df['Productivity'], ax=ax[0,1])
sns.distplot(df['Effectivness'], ax=ax[0,2])
sns.distplot(df['Usefull'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(30.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_4404/240210467.py:18: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['I find this scenario useful:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I find this scenario useful:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['I find this scenario useful:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['Total Usefulnes - EARSS'].mean(), 
dataset['Total Usefulnes - EARSS'].median(), 
float(dataset['Total Usefulnes - EARSS'].std()))
# Out:
# 3.3412698412698414 1.1089113746624435 4.0
# 3.2857142857142856 4.0 1.1491007595038465
# 3.361111111111111 4.0 1.1151597332369125
# 3.4722222222222223 4.0 1.0763771972404783
# 3.365079365079365 3.5 1.0057854523436935

# %% [markdown]
# **Entertainment - EARSS**

# %%
Enjoyable = dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:3']
Pleasing = dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:3']
Entertaining = dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:3']



df=pd.DataFrame()
df['Enjoyable']=Enjoyable
df['Pleasing']=Pleasing
df['Entertaining']=Entertaining



fig, ax = plt.subplots(2,2)
sns.distplot(df['Enjoyable'], ax=ax[0,0])
sns.distplot(df['Pleasing'], ax=ax[0,1])
sns.distplot(df['Entertaining'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_4404/3499565971.py:19: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['Total Entertainment - EARSS'].mean(), 
dataset['Total Entertainment - EARSS'].median(), 
float(dataset['Total Entertainment - EARSS'].std()))
# Out:
# 3.1626984126984126 3.0 1.0865519223661013
# 3.138888888888889 3.0 0.9821897823137986
# 3.2023809523809526 3.0 1.0908503416339548
# 3.167989417989416 3.0 0.9491255572800077

# %% [markdown]
# **Informativeness - EARSS**

# %%
Good_Product_Information = dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:3']
Relevent_Information = dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:3']
Informative = dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:3']


df=pd.DataFrame()
df['Good_Product_Information']=Good_Product_Information
df['Relevent_Information']=Relevent_Information
df['Informative']=Informative



fig, ax = plt.subplots(2,2)
sns.distplot(df['Good_Product_Information'], ax=ax[0,0])
sns.distplot(df['Relevent_Information'], ax=ax[0,1])
sns.distplot(df['Informative'], ax=ax[1,0])

sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_4404/689399714.py:19: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['Total Information - EARSS'].mean(), 
dataset['Total Information - EARSS'].median(), 
float(dataset['Total Information - EARSS'].std()))
# Out:
# 3.5952380952380953 4.0 0.983356083070976
# 3.7023809523809526 4.0 0.9074252604490793
# 3.6984126984126986 4.0 0.9170352478146756
# 3.665343915343915 3.6666666666666665 0.8450035510076845

# %% [markdown]
# **Irritation - EARSS**

# %%
Annoying = dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:3']
Frustrating = dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:3']
irritating = dataset['This scenario is irritating:After looking at the pictures please rate the following statements:3']


df=pd.DataFrame()
df['Annoying']=Annoying
df['Frustrating']=Frustrating
df['irritating']=irritating



fig, ax = plt.subplots(2,2)
sns.distplot(df['Annoying'], ax=ax[0,0])
sns.distplot(df['Frustrating'], ax=ax[0,1])
sns.distplot(df['irritating'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_4404/839935416.py:18: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:3'].std(), 
dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:3'].mode())

print (dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['This scenario is irritating:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['This scenario is irritating:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['This scenario is irritating:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['Total Irritation - EARSS'].mean(), 
dataset['Total Irritation - EARSS'].median(), 
float(dataset['Total Irritation - EARSS'].std()))
# Out:
# 2.5555555555555554 1.174466433439366 0    2
# 1    3
# Name: The shown scenario is annoying:After looking at the pictures please rate the following statements:3, dtype: int64
# 2.2817460317460316 1.1023264636460062 2.0
# 2.5396825396825395 1.2474726235978861 2.0
# 2.458994708994707 2.3333333333333335 1.0399685245553056

# %% [markdown]
# **Purchase Intention - EARSS**

# %%
Definitely_buy = dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:3']
Buy_in_near_future = dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3']
Buy_Today = dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3']
Expect_to_buy = dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:3']


df=pd.DataFrame()
df['Definitely_buy']=Definitely_buy
df['Buy_in_near_future']=Buy_in_near_future
df['Buy_Today']=Buy_Today
df['Expect_to_buy']=Expect_to_buy


fig, ax = plt.subplots(2,2)
sns.distplot(df['Definitely_buy'], ax=ax[0,0])
sns.distplot(df['Buy_in_near_future'], ax=ax[0,1])
sns.distplot(df['Buy_Today'], ax=ax[1,0])
sns.distplot(df['Expect_to_buy'], ax=ax[1,1])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_4404/1189649367.py:20: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3'].median(), 
float(dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:3'].std()))

print (dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['Total Purchase Intention - EARSS'].mean(), 
dataset['Total Purchase Intention - EARSS'].median(), 
float(dataset['Total Purchase Intention - EARSS'].std()))
# Out:
# 3.0317460317460316 1.0632319962607597 3.0
# 3.1507936507936507 1.104625986837255 4.0
# 3.1587301587301586 3.0 1.0926243010067886
# 3.138888888888889 1.0488827083198122 3.0
# 3.1200396825396823 3.0 0.9827826572579864

# %% [markdown]
# **Trust - EARSS**

# %%
Confident = dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:3']
Reliable = dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:3']
Feeling_Safe = dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:3']
Must_Be_Caarefull = dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:3']
Good_Assisting = dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:3']
Good_Decision_Maker = dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:3']


df=pd.DataFrame()
df['Confident']=Confident
df['Reliable']=Reliable
df['Feeling_Safe']=Feeling_Safe
df['Must_Be_Caarefull']=Must_Be_Caarefull
df['total purchase'] = Good_Assisting
df['Good Decision Maker'] = Good_Decision_Maker


fig, ax = plt.subplots(2,3)
sns.distplot(df['Confident'], ax=ax[0,0])
sns.distplot(df['Reliable'], ax=ax[0,1])
sns.distplot(df['Feeling_Safe'], ax=ax[0,2])
sns.distplot(df['Must_Be_Caarefull'], ax=ax[1,0])
sns.distplot(df['Good Decision Maker'], ax=ax[1,1])


sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_4404/2073739898.py:27: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:3'].mode()))

print (dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:3'].mean(), 
dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:3'].std(), 
float(dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:3'].mode()))
# Out:
# 3.2222222222222223 0.9437476272217462 3.0
# 3.0952380952380953 1.0014218690531345 3.0
# 3.1706349206349205 0.9933297427037175 3.0
# 3.1825396825396823 1.099806528808345 3.0
# 2.9523809523809526 1.1281062851310062 3.0
# 3.1785714285714284 1.1892015562936238 4.0

# %% [markdown]
# **Total Grades of EARSS**

# %%
print((dataset['Total Usefulnes - EARSS'].mean() +
dataset['Total Entertainment - EARSS'].mean() +
dataset['Total Information - EARSS'].mean() +
dataset['Total Irritation - EARSS'].mean() +
dataset['Total Purchase Intention - EARSS'].mean() +
dataset['Total Trust in Application - EARSS'].mean()) / 6)
# Out:
# 3.1518408289241613

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Usefulnes - EARSS'].mean()
median=dataset['Total Usefulnes - EARSS'].median()
mode=dataset['Total Usefulnes - EARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Usefulnes - EARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Usefulnes - EARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Entertainment - EARSS'].mean()
median=dataset['Total Entertainment - EARSS'].median()
mode=dataset['Total Entertainment - EARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Entertainment - EARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Entertainment - EARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Information - EARSS'].mean()
median=dataset['Total Information - EARSS'].median()
mode=dataset['Total Information - EARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Information - EARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Information - EARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Irritation - EARSS'].mean()
median=dataset['Total Irritation - EARSS'].median()
mode=dataset['Total Irritation - EARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Irritation - EARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Irritation - EARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Purchase Intention - EARSS'].mean()
median=dataset['Total Purchase Intention - EARSS'].median()
mode=dataset['Total Purchase Intention - EARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Purchase Intention - EARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Purchase Intention - EARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Trust in Application - EARSS'].mean()
median=dataset['Total Trust in Application - EARSS'].median()
mode=dataset['Total Trust in Application - EARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Trust in Application - EARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Trust in Application - EARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()
