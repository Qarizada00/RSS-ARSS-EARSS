# %%
#Inspired from Lecute slides
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.ticker as ticker
import plotly.graph_objs as go
import plotly.offline as py
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
dataset = pd.read_excel('C:/Users/Nasibullah Qarizada/Desktop/data science/term project/AllDataARSAA.xlsx')

# %% [markdown]
# **Usefulness - ARSS**

# %%
Performance = dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:2']
Productivity = dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:2']
Effectivness = dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:2']
Usefull = dataset['I find this scenario useful:After looking at the pictures please rate the following statements:2']

df=pd.DataFrame()
df['Performance']=Performance
df['Productivity']=Productivity
df['Effectivness']=Effectivness
df['Usefull']=Usefull

fig, ax =plt.subplots(2,3)
sns.distplot(df['Performance'], ax=ax[0,0])
sns.distplot(df['Productivity'], ax=ax[0,1])
sns.distplot(df['Effectivness'], ax=ax[0,2])
sns.distplot(df['Usefull'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(30.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21816/2427239712.py:18: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print(dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:2'].mode()),
dataset['This scenario can improve my shopping performance:After looking at the pictures please rate the following statements:2'].std())

print(dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:2'].mode()),
dataset['This scenario can increase my shopping productivity:After looking at the pictures please rate the following statements:2'].std())

print (dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['This scenario can increase my shopping effectiveness:After looking at the pictures please rate the following statements:2'].std())

print (dataset['I find this scenario useful:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I find this scenario useful:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['I find this scenario useful:After looking at the pictures please rate the following statements:2'].mode()),
dataset['I find this scenario useful:After looking at the pictures please rate the following statements:2'].std())

print (dataset['Total Usefulnes - ARSS'].mean(), 
dataset['Total Usefulnes - ARSS'].median(), 
float(dataset['Total Usefulnes - ARSS'].mode()), 
dataset['Total Usefulnes - ARSS'].std())
# Out:
# 3.2063492063492065 3.0 4.0 1.0510284116952333
# 3.2023809523809526 3.0 4.0 0.9913542016362671
# 3.1984126984126986 3.0 4.0 1.0675946921051145
# 3.357142857142857 4.0 4.0 1.0096292224185688
# 3.2410714285714284 3.25 4.0 0.9312361888904155

# %% [markdown]
# **Entertainment - ARSS**

# %%
Enjoyable = dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:2']
Pleasing = dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:2']
Entertaining = dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:2']



df=pd.DataFrame()
df['Enjoyable']=Enjoyable
df['Pleasing']=Pleasing
df['Entertaining']=Entertaining



fig, ax = plt.subplots(2,2)
sns.distplot(df['Enjoyable'], ax=ax[0,0])
sns.distplot(df['Pleasing'], ax=ax[0,1])
sns.distplot(df['Entertaining'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21816/394703169.py:19: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:2'].mode()),
dataset['The shown scenario is enjoyable:After looking at the pictures please rate the following statements:2'].std())

print (dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['The shown scenario is pleasing:After looking at the pictures please rate the following statements:2'].std())

print (dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['This scenario is entertaining:After looking at the pictures please rate the following statements:2'].std())

print (dataset['Total Entertainment - ARSS'].mean(), 
dataset['Total Entertainment - ARSS'].median(), 
float(dataset['Total Entertainment - ARSS'].mode()),
dataset['Total Entertainment - ARSS'].std())
# Out:
# 3.142857142857143 3.0 3.0 1.02334725923152
# 3.0674603174603177 3.0 3.0 0.9611024019865311
# 3.0793650793650795 3.0 3.0 1.0756498978940292
# 3.096560846560847 3.0 3.0 0.9189975615828897

# %% [markdown]
# **Informativeness - ARSS**

# %%
Good_Product_Information = dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:2']
Relevent_Information = dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:2']
Informative = dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:2']


df=pd.DataFrame()
df['Good_Product_Information']=Good_Product_Information
df['Relevent_Information']=Relevent_Information
df['Informative']=Informative



fig, ax = plt.subplots(2,2)
sns.distplot(df['Good_Product_Information'], ax=ax[0,0])
sns.distplot(df['Relevent_Information'], ax=ax[0,1])
sns.distplot(df['Informative'], ax=ax[1,0])

sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21816/3800636632.py:19: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:2'].mode()),
dataset['The shown scenario offers a good source of product information:After looking at the pictures please rate the following statements:2'].std())

print (dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:2'].mode()),
dataset['This scenario supplies relevant information:After looking at the pictures please rate the following statements:2'].std())

print (dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:2'].mode()),
dataset['This scenario is informative concerning the shown products:After looking at the pictures please rate the following statements:2'].std())

print (dataset['Total Information - ARSS'].mean(), 
dataset['Total Information - ARSS'].median(), 
float(dataset['Total Information - ARSS'].mode()),
dataset['Total Information - ARSS'].std())
# Out:
# 3.3452380952380953 4.0 4.0 1.027440803374766
# 3.3968253968253967 4.0 4.0 0.9825518858747839
# 3.3095238095238093 3.0 4.0 1.0135676071439776
# 3.3505291005290982 3.3333333333333335 4.0 0.9128295556856316

# %% [markdown]
# **Irritation - ARSS**

# %%
Annoying = dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:2']
Frustrating = dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:2']
irritating = dataset['This scenario is irritating:After looking at the pictures please rate the following statements:2']


df=pd.DataFrame()
df['Annoying']=Annoying
df['Frustrating']=Frustrating
df['irritating']=irritating



fig, ax = plt.subplots(2,2)
sns.distplot(df['Annoying'], ax=ax[0,0])
sns.distplot(df['Frustrating'], ax=ax[0,1])
sns.distplot(df['irritating'], ax=ax[1,0])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21816/1258885774.py:18: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['The shown scenario is annoying:After looking at the pictures please rate the following statements:2'].std())

print (dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['The shown scenario is frustrating:After looking at the pictures please rate the following statements:2'].std())

print (dataset['This scenario is irritating:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['This scenario is irritating:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['This scenario is irritating:After looking at the pictures please rate the following statements:2'].mode()),
dataset['This scenario is irritating:After looking at the pictures please rate the following statements:2'].std())

print (dataset['Total Irritation -ARSS'].mean(), 
dataset['Total Irritation -ARSS'].median(), 
float(dataset['Total Irritation -ARSS'].mode()),
dataset['Total Irritation -ARSS'].std())
# Out:
# 2.503968253968254 2.0 2.0 1.1308707496326145
# 2.388888888888889 2.0 2.0 1.0966971219286423
# 2.5555555555555554 2.0 2.0 1.1470075777236464
# 2.4828042328042335 2.3333333333333335 2.0 1.0038282995688117

# %% [markdown]
# **Purchase Intention - ARSS**

# %%
Definitely_buy = dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:2']
Buy_in_near_future = dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2']
Buy_Today = dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2']
Expect_to_buy = dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:2']


df=pd.DataFrame()
df['Definitely_buy']=Definitely_buy
df['Buy_in_near_future']=Buy_in_near_future
df['Buy_Today']=Buy_Today
df['Expect_to_buy']=Expect_to_buy


fig, ax = plt.subplots(2,2)
sns.distplot(df['Definitely_buy'], ax=ax[0,0])
sns.distplot(df['Buy_in_near_future'], ax=ax[0,1])
sns.distplot(df['Buy_Today'], ax=ax[1,0])
sns.distplot(df['Expect_to_buy'], ax=ax[1,1])
sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21816/2832398946.py:20: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['I would definitely buy products in this scenario:After looking at the pictures please rate the following statements:2'].std())

print (dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['I would intend to purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].std())

print (dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].median(),
float(dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].mode()),
dataset['If it would exist today, it is likely that I would purchase products in this scenario in the near future:After looking at the pictures please rate the following statements:2'].std())

print (dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['I would expect to purchase products in this scenario in the near future if it would exist today:After looking at the pictures please rate the following statements:2'].std())

print (dataset['Total Purchase Intention - ARSS'].mean(), 
dataset['Total Purchase Intention - ARSS'].median(), 
float(dataset['Total Purchase Intention - ARSS'].mode()), 
dataset['Total Purchase Intention - ARSS'].std())
# Out:
# 2.984126984126984 3.0 3.0 1.0018638167519405
# 3.0833333333333335 3.0 4.0 0.9925017687420895
# 3.0674603174603177 3.0 3.0 1.040711476301226
# 3.1031746031746033 3.0 3.0 1.0085638488074797
# 3.0595238095238093 3.0 3.0 0.9233192825013552

# %% [markdown]
# **Trust - ARSS**

# %%
Confident = dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:2']
Reliable = dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:2']
Feeling_Safe = dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:2']
Must_Be_Caarefull = dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:2']
Good_Assisting = dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:2']
Good_Decision_Maker = dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:2']


df=pd.DataFrame()
df['Confident']=Confident
df['Reliable']=Reliable
df['Feeling_Safe']=Feeling_Safe
df['Must_Be_Caarefull']=Must_Be_Caarefull
df['total purchase'] = Good_Assisting
df['Good Decision Maker'] = Good_Decision_Maker


fig, ax = plt.subplots(2,3)
sns.distplot(df['Confident'], ax=ax[0,0])
sns.distplot(df['Reliable'], ax=ax[0,1])
sns.distplot(df['Feeling_Safe'], ax=ax[0,2])
sns.distplot(df['Must_Be_Caarefull'], ax=ax[1,0])
sns.distplot(df['Good Decision Maker'], ax=ax[1,1])


sns.set(rc={'figure.figsize':(25.0,10.0)})
fig.show()
# Out:
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_21816/598898297.py:27: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print (dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['I am confident in the application. I feel that it works well:After looking at the pictures please rate the following statements:2'].std())

print (dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:2'].mode()),
dataset['The application seems very reliable. I count on it to be correct all the time for supporting my shopping trip:After looking at the pictures please rate the following statements:2'].std())

print(dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:2'].median(), 
dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:2'].mode(), 
dataset['I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:2'].std())

print (dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['I feel that I have to be careful when using this application:After looking at the pictures please rate the following statements:2'].std())

print (dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:2'].mode()),
dataset['The application can assist me better than a human shopping assistant:After looking at the pictures please rate the following statements:2'].std())

print (dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:2'].mean(), 
dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:2'].median(), 
float(dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:2'].mode()), 
dataset['I like using the application for decision making during my shopping trip:After looking at the pictures please rate the following statements:2'].std())

print (dataset['Total Trust in Application - ARSS'].mean(), 
dataset['Total Trust in Application - ARSS'].median(), 
float(dataset['Total Trust in Application - ARSS'].mode()),
dataset['Total Trust in Application - ARSS'].std())
# Out:
# 3.1746031746031744 3.0 3.0 0.9495594707630376
# 3.0476190476190474 3.0 3.0 0.9392473282049437
# 3.126984126984127 3.0 0    3
# 1    4
# Name: I feel safe that when I rely on the application I get the right information:After looking at the pictures please rate the following statements:2, dtype: int64 0.9777128118095443
# 3.246031746031746 3.0 4.0 1.0192295186743645
# 2.734126984126984 3.0 3.0 1.0659274022365102
# 3.0238095238095237 3.0 4.0 1.1002664343341946
# 3.0588624338624353 3.0 3.0 0.6549068595785575

# %% [markdown]
# **Total grade of ARSS**

# %%
print((dataset['Total Usefulnes - ARSS'].mean() +
dataset['Total Entertainment - ARSS'].mean() +
dataset['Total Information - ARSS'].mean() +
dataset['Total Irritation -ARSS'].mean() +
dataset['Total Purchase Intention - ARSS'].mean() +
dataset['Total Trust in Application - ARSS'].mean()) / 6)
# Out:
# 3.048225308641976

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Usefulnes - ARSS'].mean()
median=dataset['Total Usefulnes - ARSS'].median()
mode=dataset['Total Usefulnes - ARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Usefulnes - ARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Usefulnes - ARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Entertainment - ARSS'].mean()
median=dataset['Total Entertainment - ARSS'].median()
mode=dataset['Total Entertainment - ARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Entertainment - ARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Entertainment - ARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Information - ARSS'].mean()
median=dataset['Total Information - ARSS'].median()
mode=dataset['Total Information - ARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Information - ARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Information - ARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Irritation -ARSS'].mean()
median=dataset['Total Irritation -ARSS'].median()
mode=dataset['Total Irritation -ARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Irritation -ARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Irritation -ARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Purchase Intention - ARSS'].mean()
median=dataset['Total Purchase Intention - ARSS'].median()
mode=dataset['Total Purchase Intention - ARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Purchase Intention - ARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Purchase Intention - ARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=dataset['Total Trust in Application - ARSS'].mean()
median=dataset['Total Trust in Application - ARSS'].median()
mode=dataset['Total Trust in Application - ARSS'].mode().values[0]

sns.boxplot(data=dataset, x="Total Trust in Application - ARSS", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=dataset, x="Total Trust in Application - ARSS", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()
